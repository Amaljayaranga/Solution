# %% [markdown]
# <a href="https://colab.research.google.com/github/Amaljayaranga/Solution/blob/master/Solution_1.1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torchvision
from PIL import Image
import torchvision.transforms as T
import cv2
import matplotlib.pyplot as plt
import numpy as np
import os
import json

model = torchvision.models.detection.fasterrcnn_resnet50_fpn(pretrained=True)
model.eval()

COCO_INSTANCE_CATEGORY_NAMES = [
    '__background__', 'person', 'bicycle', 'car', 'motorcycle', 'airplane', 'bus',
    'train', 'truck', 'boat', 'traffic light', 'fire hydrant', 'N/A', 'stop sign',
    'parking meter', 'bench', 'bird', 'cat', 'dog', 'horse', 'sheep', 'cow',
    'elephant', 'bear', 'zebra', 'giraffe', 'N/A', 'backpack', 'umbrella', 'N/A', 'N/A',
    'handbag', 'tie', 'suitcase', 'frisbee', 'skis', 'snowboard', 'sports ball',
    'kite', 'baseball bat', 'baseball glove', 'skateboard', 'surfboard', 'tennis racket',
    'bottle', 'N/A', 'wine glass', 'cup', 'fork', 'knife', 'spoon', 'bowl',
    'banana', 'apple', 'sandwich', 'orange', 'broccoli', 'carrot', 'hot dog', 'pizza',
    'donut', 'cake', 'chair', 'couch', 'potted plant', 'bed', 'N/A', 'dining table',
    'N/A', 'N/A', 'toilet', 'N/A', 'tv', 'laptop', 'mouse', 'remote', 'keyboard', 'cell phone',
    'microwave', 'oven', 'toaster', 'sink', 'refrigerator', 'N/A', 'book',
    'clock', 'vase', 'scissors', 'teddy bear', 'hair drier', 'toothbrush'
]

def get_prediction(img_path, threshold):
    img = Image.open(img_path)
    transform = T.Compose([T.ToTensor()])
    img = transform(img)
    pred = model([img])
    pred_class = [COCO_INSTANCE_CATEGORY_NAMES[i] for i in list(pred[0]['labels'].numpy())]
    pred_boxes = [[(i[0], i[1]), (i[2], i[3])] for i in list(pred[0]['boxes'].detach().numpy())]
    pred_score = list(pred[0]['scores'].detach().numpy())
    pred_t = [pred_score.index(x) for x in pred_score if x > threshold][-1]
    pred_boxes = pred_boxes[:pred_t + 1]
    pred_class = pred_class[:pred_t + 1]
    return pred_boxes, pred_class

def object_detection_api(img_path, threshold=0.5, rect_th=3, text_size=3, text_th=3):
  boxes, pred_cls = get_prediction(img_path, threshold)
  img = cv2.imread(img_path)
  img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
  for i in range(len(boxes)):
    cv2.rectangle(img, boxes[i][0], boxes[i][1],color=(0, 255, 0), thickness=rect_th)
    cv2.putText(img,pred_cls[i], boxes[i][0], cv2.FONT_HERSHEY_SIMPLEX, text_size, (0,255,0),thickness=text_th)
  plt.figure(figsize=(20,30))
  plt.imshow(img)
  plt.xticks([])
  plt.yticks([])
  plt.show()

object_detection_api('00000.jpg', threshold=0.9)

# %%
# !unzip 'Horse.zip'

# %%
import torchvision
from PIL import Image
import torchvision.transforms as T
import cv2
import matplotlib.pyplot as plt
import numpy as np
import os
import json
import torch.nn as nn

model = torchvision.models.detection.fasterrcnn_resnet50_fpn(pretrained=True)
model.eval()

COCO_INSTANCE_CATEGORY_NAMES = [
    '__background__', 'person', 'bicycle', 'car', 'motorcycle', 'airplane', 'bus',
    'train', 'truck', 'boat', 'traffic light', 'fire hydrant', 'N/A', 'stop sign',
    'parking meter', 'bench', 'bird', 'cat', 'dog', 'horse', 'sheep', 'cow',
    'elephant', 'bear', 'zebra', 'giraffe', 'N/A', 'backpack', 'umbrella', 'N/A', 'N/A',
    'handbag', 'tie', 'suitcase', 'frisbee', 'skis', 'snowboard', 'sports ball',
    'kite', 'baseball bat', 'baseball glove', 'skateboard', 'surfboard', 'tennis racket',
    'bottle', 'N/A', 'wine glass', 'cup', 'fork', 'knife', 'spoon', 'bowl',
    'banana', 'apple', 'sandwich', 'orange', 'broccoli', 'carrot', 'hot dog', 'pizza',
    'donut', 'cake', 'chair', 'couch', 'potted plant', 'bed', 'N/A', 'dining table',
    'N/A', 'N/A', 'toilet', 'N/A', 'tv', 'laptop', 'mouse', 'remote', 'keyboard', 'cell phone',
    'microwave', 'oven', 'toaster', 'sink', 'refrigerator', 'N/A', 'book',
    'clock', 'vase', 'scissors', 'teddy bear', 'hair drier', 'toothbrush'
]

def get_prediction(img_path, threshold):
    img = Image.open(img_path)
    transform = T.Compose([T.ToTensor()])
    img = transform(img)
    pred = model([img])
    pred_class = [COCO_INSTANCE_CATEGORY_NAMES[i] for i in list(pred[0]['labels'].numpy())]
    pred_boxes = [[(i[0], i[1]), (i[2], i[3])] for i in list(pred[0]['boxes'].detach().numpy())]
    pred_score = list(pred[0]['scores'].detach().numpy())
    pred_t = [pred_score.index(x) for x in pred_score if x > threshold][-1]
    pred_boxes = pred_boxes[:pred_t + 1]
    pred_class = pred_class[:pred_t + 1]
    return pred_boxes, pred_class

def object_detection_api(img_path, threshold=0.5, rect_th=3, text_size=3, text_th=3):
  boxes, pred_cls = get_prediction(img_path, threshold)
  img = cv2.imread(img_path)
  img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
  for i in range(len(boxes)):
    cv2.rectangle(img, boxes[i][0], boxes[i][1],color=(0, 255, 0), thickness=rect_th)
    cv2.putText(img,pred_cls[i], boxes[i][0], cv2.FONT_HERSHEY_SIMPLEX, text_size, (0,255,0),thickness=text_th)
  plt.figure(figsize=(20,30))
  plt.imshow(img)
  plt.xticks([])
  plt.yticks([])
  plt.show()

#object_detection_api('./bird.jpg', threshold=0.5)
#boxes, pred_cls = get_prediction('./2.jpg', threshold=0.6)
#print(pred_cls)
#print(boxes)

img_data = {}
img_data['imgs'] = []
path = './Horse/'

images = os.listdir(path)
for image in images:
    boxes, pred_cls = get_prediction(path+image, threshold=0.9)
    np_boxes = np.array(boxes)
    np_classes = np.array(pred_cls)
    img_object = []

    for class_, box_ in zip(np_classes, np_boxes):
      object = {}
      object["class"] = class_
      object["x"] = int(box_[0][0])
      object["y"] = int(box_[0][1])
      object["width"] = int(box_[1][0] - box_[0][0])
      object["height"] = int(box_[1][1] - box_[0][1])
      img_object.append(object)

    single_image = {}
    single_image["index"] = image.split('.')[0]
    single_image["objects"] = img_object
    img_data['imgs'].append(single_image)

print(img_data)
with open('people-horse-json.txt', 'w') as outfile:
    json.dump(img_data, outfile)
# Out:
# Downloading: "https://download.pytorch.org/models/fasterrcnn_resnet50_fpn_coco-258fb6c6.pth" to /root/.cache/torch/checkpoints/fasterrcnn_resnet50_fpn_coco-258fb6c6.pth
# HBox(children=(IntProgress(value=0, max=167502836), HTML(value='')))
# {'imgs': [{'index': '00036', 'objects': [{'class': 'horse', 'x': 178, 'y': 159, 'width': 294, 'height': 193}, {'class': 'person', 'x': 324, 'y': 97, 'width': 69, 'height': 160}]}, {'index': '00039', 'objects': [{'class': 'horse', 'x': 206, 'y': 151, 'width': 293, 'height': 199}, {'class': 'person', 'x': 346, 'y': 106, 'width': 72, 'height': 149}, {'class': 'potted plant', 'x': 111, 'y': 280, 'width': 103, 'height': 155}]}, {'index': '00001', 'objects': [{'class': 'horse', 'x': 135, 'y': 175, 'width': 334, 'height': 214}, {'class': 'person', 'x': 296, 'y': 140, 'width': 67, 'height': 150}, {'class': 'baseball bat', 'x': 754, 'y': 324, 'width': 98, 'height': 66}]}, {'index': '00040', 'objects': [{'class': 'horse', 'x': 221, 'y': 155, 'width': 286, 'height': 192}, {'class': 'person', 'x': 360, 'y': 105, 'width': 65, 'height': 153}, {'class': 'potted plant', 'x': 105, 'y': 291, 'width': 123, 'height': 143}]}, {'index': '00057', 'objects': [{'class': 'horse', 'x': 462, 'y': 140, 'width': 212, 'height': 193}, {'class': 'person', 'x': 548, 'y': 103, 'width': 67, 'height': 141}, {'class': 'potted plant', 'x': 3, 'y': 310, 'width': 98, 'height': 138}]}, {'index': '00021', 'objects': [{'class': 'person', 'x': 279, 'y': 73, 'width': 81, 'height': 157}, {'class': 'horse', 'x': 125, 'y': 111, 'width': 311, 'height': 254}]}, {'index': '00027', 'objects': [{'class': 'person', 'x': 289, 'y': 79, 'width': 69, 'height': 135}, {'class': 'horse', 'x': 151, 'y': 123, 'width': 307, 'height': 233}, {'class': 'potted plant', 'x': 308, 'y': 297, 'width': 94, 'height': 146}]}, {'index': '00028', 'objects': [{'class': 'person', 'x': 287, 'y': 80, 'width': 71, 'height': 155}, {'class': 'horse', 'x': 154, 'y': 133, 'width': 296, 'height': 235}, {'class': 'potted plant', 'x': 301, 'y': 333, 'width': 65, 'height': 114}]}, {'index': '00043', 'objects': [{'class': 'horse', 'x': 230, 'y': 158, 'width': 301, 'height': 200}, {'class': 'person', 'x': 392, 'y': 105, 'width': 65, 'height': 147}, {'class': 'potted plant', 'x': 86, 'y': 297, 'width': 87, 'height': 144}]}, {'index': '00050', 'objects': [{'class': 'horse', 'x': 347, 'y': 163, 'width': 268, 'height': 190}, {'class': 'person', 'x': 471, 'y': 115, 'width': 70, 'height': 138}, {'class': 'potted plant', 'x': 12, 'y': 302, 'width': 125, 'height': 141}]}, {'index': '00004', 'objects': [{'class': 'horse', 'x': 131, 'y': 174, 'width': 333, 'height': 207}, {'class': 'person', 'x': 290, 'y': 127, 'width': 71, 'height': 156}]}, {'index': '00014', 'objects': [{'class': 'horse', 'x': 123, 'y': 178, 'width': 335, 'height': 199}, {'class': 'person', 'x': 296, 'y': 135, 'width': 63, 'height': 157}]}, {'index': '00037', 'objects': [{'class': 'person', 'x': 333, 'y': 100, 'width': 71, 'height': 161}, {'class': 'horse', 'x': 183, 'y': 157, 'width': 298, 'height': 191}]}, {'index': '00035', 'objects': [{'class': 'person', 'x': 313, 'y': 95, 'width': 71, 'height': 160}, {'class': 'horse', 'x': 170, 'y': 157, 'width': 293, 'height': 203}]}, {'index': '00031', 'objects': [{'class': 'person', 'x': 292, 'y': 86, 'width': 68, 'height': 158}, {'class': 'horse', 'x': 130, 'y': 144, 'width': 324, 'height': 204}, {'class': 'potted plant', 'x': 212, 'y': 299, 'width': 112, 'height': 152}]}, {'index': '00046', 'objects': [{'class': 'person', 'x': 418, 'y': 106, 'width': 76, 'height': 150}, {'class': 'horse', 'x': 260, 'y': 157, 'width': 317, 'height': 202}, {'class': 'potted plant', 'x': 68, 'y': 309, 'width': 83, 'height': 135}]}, {'index': '00016', 'objects': [{'class': 'person', 'x': 297, 'y': 119, 'width': 63, 'height': 144}, {'class': 'horse', 'x': 126, 'y': 145, 'width': 346, 'height': 228}]}, {'index': '00007', 'objects': [{'class': 'horse', 'x': 107, 'y': 176, 'width': 350, 'height': 205}, {'class': 'person', 'x': 273, 'y': 118, 'width': 71, 'height': 162}, {'class': 'potted plant', 'x': 0, 'y': 168, 'width': 57, 'height': 129}, {'class': 'potted plant', 'x': 722, 'y': 275, 'width': 77, 'height': 143}]}, {'index': '00030', 'ob ...

# %%
import cv2
import os
import numpy as np


path = './Horse/'
memmaps = []


for filename in os.listdir(path):
    memmap_filename = filename.split('.')[0]+'.mmap'
    memmap_filename = path+'memmap/'+memmap_filename
    os.makedirs(os.path.dirname(memmap_filename), exist_ok=True)

    im = cv2.imread(path+filename)
    if not (im is None):
      dtype = im.dtype
      shape = im.shape
      fp = np.memmap(memmap_filename, dtype=dtype, mode='w+', shape=shape)
      fp[:] = im[:]
      memmaps.append(fp)

complete_memmap = path + 'memmap/'+'people-horse.mmap'

os.makedirs(os.path.dirname(path + 'memmap'), exist_ok=True)
complete_shape = (len(memmaps), shape[0], shape[1], shape[2])
    # print("Complete shape ",complete_shape) #(82, 480, 854, 3)
    # complete_shape=(82,480,854,3)
    # print(complete_shape)
fpc = np.memmap(complete_memmap, dtype=dtype, mode='w+', shape=complete_shape)
fpc[:] = memmaps[:]

# %%
from torch.utils.data import Dataset
import numpy as np
import json
import matplotlib.pyplot as plt
import torchvision.transforms as transforms
import torch
import torch.nn as nn
import cv2

class DavisDataset(Dataset):

    def __init__(self, memmap, json_data, need_classes):

        ##cropping objects from memaps and add to idxes
        self.memmap = memmap
        self.json_data = json_data
        self.idxes = {}
        self.max_no_classes = 0
        self.need_classes = need_classes

        imgs = self.json_data['imgs']
        for img in imgs:
            idx = int(img['index'])
            classes = img['objects']
            classes_ = []
            objects_ = []
            class_objects = []
            for class_idx, class_ in enumerate(classes):
              if class_['class']  in self.need_classes:
                  single_class = class_['class']
                  x = class_['x']
                  y = class_['y']
                  width = class_['width']
                  height = class_['height']

                  if class_idx > self.max_no_classes:
                      self.max_no_classes = class_idx

                  image = self.memmap[idx]
                  crop_img = image[y:y + height, x:x + width]
                  img_resized = cv2.resize(crop_img, (200,200), interpolation = cv2.INTER_AREA)
                  classes_.append(single_class)
                  objects_.append(self.image_to_tensor(img_resized))
                  #objects_.append(img_resized)

            class_objects.append(classes_)
            class_objects.append(objects_)
            self.idxes[idx] = class_objects

    def image_to_tensor(self,image, mean=0, std=1.):
        image = image.astype(np.float32)
        image = (image - mean) / std
        image = image.transpose((2, 0, 1))
        tensor = torch.from_numpy(image)
        return tensor

    def __len__(self):
        return len(self.memmap)

    def __getitem__(self, index):
        classes, images = self.idxes.get(index)
        return [classes, images]

class Encoder(nn.Module):

    def __init__(self):
        super(Encoder, self).__init__()

        self.conv = nn.Sequential(nn.Conv2d(in_channels=3, out_channels=32, kernel_size=5),
                                  nn.ReLU(),
                                  nn.MaxPool2d(kernel_size=2, stride=2),
                                  nn.Conv2d(in_channels=32, out_channels=64, kernel_size=5),
                                  nn.ReLU(),
                                  nn.MaxPool2d(kernel_size=2, stride=2)
                                  )
        # output 64, 47, 47
        self.fc = nn.Sequential(nn.Linear(64 * 47 * 47, 1024),
                                nn.ReLU(),
                                nn.Linear(1024, 1024),
                                nn.ReLU(),
                                nn.Linear(1024, 256)
                                )

    def forward(self, x):
        x = self.conv(x)
        x = x.view(x.size()[0], -1)
        z = self.fc(x)
        return z


#loading memmap and json for same context
folder_path='./drive/My Drive/Thesis_2020/'
complete_shape=(43,480,854,3)
complete_memmap = folder_path+'all-people.mmap'
newfp = np.memmap(complete_memmap, dtype='uint8', mode='r', shape=complete_shape)
#loading json
with open(folder_path+'all-people-json.txt') as json_file:
    data_json = json.load(json_file)




def show_objects(classes,images):
  img_np = []
  for i in range(len(classes)):
    img_np_i = np.asarray(images[i])
    img_np.append(img_np_i)

  f, axarr = plt.subplots(1, len(classes))
  for i in range(len(classes)):
    axarr[i].imshow(img_np[i], interpolation='nearest')
  plt.show()

need_classes = ['person']
same_conext_ds = DavisDataset(newfp, data_json, need_classes)
same_conext_dl = torch.utils.data.DataLoader(same_conext_ds, batch_size=1, shuffle=True)

encoder = Encoder()

one_image_zs = []
object_zs_same = []

for batch in same_conext_dl:
    class_label , images = batch[0], batch[1]
    single_block = []

    #store z of each image objects per image 
    for i in range(len(class_label)):
      single_block.append([class_label[i],images[i],encoder(images[i])])
    one_image_zs.append(single_block)

    #store main Z and avg Z per image
    for one_img_z in one_image_zs:
      no_objects = len(one_img_z)
      all_zs_in_one_image = [one_img_z[i][2] for i in range(no_objects)]
      for index in range(no_objects):
        main_z = all_zs_in_one_image[index]
        contexr_avg_z = torch.mean(torch.stack(all_zs_in_one_image), dim=0)
        object_zs_same.append([main_z,contexr_avg_z])

 


      


   





    
      




'''
def show_images():
  for i in range(43):
    classes, images  = davisdt.__getitem__(i)
    print('index : ', i, classes)
    show_objects(classes,images)
'''

# %%
from torch.utils.data import Dataset
import numpy as np
import json
import matplotlib.pyplot as plt
import torchvision.transforms as transforms
import torch
import torch.nn as nn
import cv2

class DavisDataset(Dataset):

    def __init__(self, memmap, json_data, need_classes):

        ##cropping objects from memaps and add to idxes
        self.memmap = memmap
        self.json_data = json_data
        self.idxes = {}
        self.max_no_classes = 0
        self.need_classes = need_classes

        imgs = self.json_data['imgs']
        for img in imgs:
            idx = int(img['index'])
            classes = img['objects']
            classes_ = []
            objects_ = []
            class_objects = []
            for class_idx, class_ in enumerate(classes):
              if class_['class']  in self.need_classes:
                  single_class = class_['class']
                  x = class_['x']
                  y = class_['y']
                  width = class_['width']
                  height = class_['height']

                  if class_idx > self.max_no_classes:
                      self.max_no_classes = class_idx

                  image = self.memmap[idx]
                  crop_img = image[y:y + height, x:x + width]
                  img_resized = cv2.resize(crop_img, (200,200), interpolation = cv2.INTER_AREA)
                  classes_.append(single_class)
                  objects_.append(self.image_to_tensor(img_resized))
                  #objects_.append(img_resized)

            class_objects.append(classes_)
            class_objects.append(objects_)
            self.idxes[idx] = class_objects

    def image_to_tensor(self,image, mean=0, std=1.):
        image = image.astype(np.float32)
        image = (image - mean) / std
        image = image.transpose((2, 0, 1))
        tensor = torch.from_numpy(image)
        return tensor

    def __len__(self):
        return len(self.memmap)

    def __getitem__(self, index):
        classes, images = self.idxes.get(index)
        return [classes, images]

class Model(nn.Module):

    def __init__(self):
        super(Model, self).__init__()

        self.conv = nn.Sequential(nn.Conv2d(in_channels=3, out_channels=32, kernel_size=5),
                                  nn.ReLU(),
                                  nn.MaxPool2d(kernel_size=2, stride=2),
                                  nn.Conv2d(in_channels=32, out_channels=64, kernel_size=5),
                                  nn.ReLU(),
                                  nn.MaxPool2d(kernel_size=2, stride=2)
                                  )
        # output 64, 47, 47
        self.fc = nn.Sequential(nn.Linear(64 * 47 * 47, 1024),
                                nn.ReLU(),
                                nn.Linear(1024, 1024),
                                nn.ReLU(),
                                nn.Linear(1024, 256)
                                )
        
        self.simase = nn.Sequential(nn.Linear(256, 128),
                                nn.ReLU(),
                                nn.Linear(128, 128),
                                nn.ReLU(),
                                nn.Linear(128, 64)
                                )
        
    def forward_to_get_z(self, x):
        x = self.conv(x)
        x = x.view(x.size()[0], -1)
        z = self.fc(x)
        return z

    def get_zs(self,x):
        class_labels , object_images = x[0], x[1]
        is_same_class = not (class_labels.count(class_labels[0]) == len(class_labels))
        all_zs = [self.forward_to_get_z(object_images[i]) for i in range(len(class_labels))]
        object_zs = []
        for index in range(len(all_zs)):
          main_z = all_zs[index]
          context_avg_z = torch.mean(torch.stack(all_zs), dim=0)
          object_zs.append([main_z,context_avg_z,int(is_same_class)])
        return object_zs


    def forward(self, x):
        zs = self.get_zs(x)
        
       
        


#loading memmap and json for same context
folder_path='./drive/My Drive/Thesis_2020/'
complete_shape=(43,480,854,3)
complete_memmap = folder_path+'all-people.mmap'
newfp = np.memmap(complete_memmap, dtype='uint8', mode='r', shape=complete_shape)
#loading json
with open(folder_path+'all-people-json.txt') as json_file:
    data_json = json.load(json_file)




def show_objects(classes,images):
  img_np = []
  for i in range(len(classes)):
    img_np_i = np.asarray(images[i])
    img_np.append(img_np_i)

  f, axarr = plt.subplots(1, len(classes))
  for i in range(len(classes)):
    axarr[i].imshow(img_np[i], interpolation='nearest')
  plt.show()

need_classes = ['person']
same_conext_ds = DavisDataset(newfp, data_json, need_classes)
same_conext_dl = torch.utils.data.DataLoader(same_conext_ds, batch_size=1, shuffle=True)

model = Model()

for batch in same_conext_dl:
    class_label , images = batch[0], batch[1]
    model(batch)

    

 


      


   





    
      




'''
def show_images():
  for i in range(43):
    classes, images  = davisdt.__getitem__(i)
    print('index : ', i, classes)
    show_objects(classes,images)
'''
# Out:
# Streaming output truncated to the last 5000 lines.
#          -1.7466e+00,  3.0466e+00, -2.6239e+00, -1.4212e+00,  3.6040e+00,
#          -3.0049e+00,  7.1843e-01, -1.3866e+00, -2.1577e+00,  1.4245e+00,
#           2.9026e-01,  2.0365e+00,  9.8270e-01, -7.9947e-01, -1.4781e+00,
#          -3.1732e+00, -6.3576e-01,  4.6064e+00, -1.2773e+00, -1.0597e+00,
#          -2.6002e+00, -1.6792e+00, -7.0607e-01,  1.1043e+00,  9.8052e-02,
#          -2.8849e+00, -5.7123e-01,  2.4242e+00,  1.3381e+00,  1.3887e-01,
#          -6.0414e-01,  5.4560e-01, -2.3448e+00,  6.3282e-01, -1.2262e+00,
#           5.7261e-01, -3.7615e+00, -1.7053e+00,  6.8760e-01, -1.4382e+00,
#          -2.8689e-01,  2.8162e+00, -3.4903e-01,  1.5488e+00, -1.9612e+00,
#          -1.4752e+00, -3.3978e-01, -3.4591e+00,  1.0185e+00, -1.8584e+00,
#          -2.5548e-01, -1.6843e-01, -9.7145e-01, -3.6871e+00, -1.1782e+00,
#           1.2374e+00, -1.0289e+00,  1.2441e+00,  3.8295e-01, -1.2099e+00,
#           1.9697e+00, -1.1418e+00, -2.9559e+00, -9.0704e-01, -2.1529e-01,
#           1.2578e+00,  1.3509e+00, -2.5633e-01, -2.3959e+00,  1.6732e+00,
#           9.8330e-01, -2.0231e+00,  1.6282e+00,  7.6608e-01, -1.4823e+00,
#           1.5843e+00, -1.0262e+00,  2.6915e+00, -1.2925e+00,  2.4596e-01,
#           1.7803e-02,  3.4671e+00,  3.3038e-01,  3.6220e-01, -1.3869e-01,
#           0.2215,  0.2687, -0.6515, -1.4249,  0.0452,  2.6526,  2.4442,  2.2354,
#           3.5190,  1.6653, -1.9079,  3.1635, -3.5227, -0.8332,  3.7458, -2.7166,
#           1.1559, -1.4346, -1.8403,  1.7186,  0.0333,  1.9876,  1.0252, -0.6143,
#          -0.9458, -3.1551,  0.8128,  4.3202, -1.5571, -1.4175, -3.0813, -2.1870,
#          -1.0839,  0.8911, -0.3062, -3.6501, -0.5542,  2.6701,  2.1172, -0.3762,
#          -0.4714,  0.6467, -1.8399, -0.0471, -1.7544,  1.3669, -4.4330, -1.5174,
#           0.0992, -1.9435, -0.6848,  3.3743, -1.2986,  1.5163, -1.6227, -1.6024,
#           0.0238, -2.6005,  1.4255, -1.8899, -0.0526, -0.3950, -1.6656, -2.5008,
#          -1.0025,  0.8499, -0.8356,  2.1928,  0.0482, -1.7124,  2.1480, -0.6707,
#          -2.8998, -1.3634, -0.2940,  0.4876,  0.6913, -1.1419, -2.4826,  2.2589,
#           1.4769, -2.2156,  2.3845,  1.8653, -1.7867,  1.5533, -0.6461,  2.9016,
#          -0.6923,  0.2072, -0.3598,  4.4842,  1.1332,  0.4964, -0.5858, -1.9148]],
#        grad_fn=<MeanBackward1>), 0]]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-20-d1a72b781858> in <module>()
#     144 for batch in same_conext_dl:
#     145     class_label , images = batch[0], batch[1]
# --> 146     model(batch)
#     147
#     148
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     530             result = self._slow_forward(*input, **kwargs)
#     531         else:
# --> 532             result = self.forward(*input, **kwargs)
#     533         for hook in self._forward_hooks.values():
#     534             hook_result = hook(self, input, result)
#
# <ipython-input-20-d1a72b781858> in forward(self, x)
#     108
#     109     def forward(self, x):
# --> 110         self.get_zs(x)
#     111
#     112
#
# <ipython-input-20-d1a72b781858> in get_zs(self, x)
#      98         class_labels , object_images = x[0], x[1]
#      99         is_same_class = not (class_labels.count(class_labels[0]) == len(class_labels))
# --> 100         all_zs = [self.forward_to_get_z(object_images[i]) for i in range(len(class_labels))]
#     101         object_zs = []
#     102         for index in range(len(all_zs)):
#
# <ipython-input-20-d1a72b781858> in <listcomp>(.0)
#      98         class_labels , object_images = x[0], x[1]
#      99         is_same_class = not (class_labels.count(class_labels[0]) == len(class_labels))
# --> 100         all_zs = [self.forward_to_get_z(object_images[i]) for i in range(len(class_labels))]
#     101         object_zs = []
#     102         for index in range(len(all_zs)):
#
# <ipython-input-20-d1a72b781858> in forward_to_get_z(self, x)
#      90
#      91     def forward_to_get_z(self, x):
# ---> 92         x = self.conv(x)
#      93         x = x.view(x.size()[0], -1)
#      94         z = self.fc(x)
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     530             result = self._slow_forward(*input, **kwargs)
#     531         else:
# --> 532             result = self.forward(*input, **kwargs)
#     533         for hook in self._forward_hooks.values():
#     534             hook_result = hook(self, input, result)
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/container.py in forward(self, input)
#      98     def forward(self, input):
#      99         for module in self:
# --> 100             input = module(input)
#     101         return input
#     102
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     530             result = self._slow_forward(*input, **kwargs)
#     531         else:
# --> 532             result = self.forward(*input, **kwargs)
#     533         for hook in self._forward_hooks.values():
#     534             hook_result = hook(self, input, result)
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/conv.py in forward(self, input)
#     343
#     344     def forward(self, input):
# --> 345         return self.conv2d_forward(input, self.weight)
#     346
#     347 class Conv3d(_ConvNd):
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/conv.py in conv2d_forward(self, input, weight)
#     340                             _pair(0), self.dilation, self.groups)
#     341         return F.conv2d(input, weight, self.bias, self.stride,
# --> 342                         self.padding, self.dilation, self.groups)
#     343
#     344     def forward(self, input):
#
# KeyboardInterrupt:

# %%
vIn = not (True) 
vOut = int(vIn)
print(vOut)
t=torch.Tensor(1)
print(t)
# Out:
# 0
# tensor([2.7578e-28])
